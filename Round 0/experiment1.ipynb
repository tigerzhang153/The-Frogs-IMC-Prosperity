# %%
import pandas as pd

df = pd.read_csv('Data (Raw CSV)/prices_round_0_day_-1.csv', sep=';')

# %%
emeralds = df[df['product'] == 'EMERALDS'].copy()
tomatoes = df[df['product'] == 'TOMATOES'].copy()

# %%
import matplotlib.pyplot as plt

plt.plot(emeralds['timestamp'], emeralds['mid_price'], label='EMERALDS')
plt.plot(tomatoes['timestamp'], tomatoes['mid_price'], label='TOMATOES')
plt.xlabel('Timestamp')
plt.ylabel('Mid Price')
plt.legend()
plt.title('Mid Price Over Time')
plt.show()

# %%
print(emeralds['mid_price'].describe())
print(tomatoes['mid_price'].describe())
# Out:
# count    10000.000000
# mean      9999.998000
# std          0.716692
# min       9996.000000
# 25%      10000.000000
# 50%      10000.000000
# 75%      10000.000000
# max      10004.000000
# Name: mid_price, dtype: float64
# count    10000.000000
# mean      4977.567750
# std         14.578497
# min       4946.500000
# 25%       4964.000000
# 50%       4980.000000
# 75%       4990.000000
# max       5011.000000
# Name: mid_price, dtype: float64

# %%
df2 = pd.read_csv('Data (Raw CSV)/prices_round_0_day_-2.csv', sep=';')

df3 = pd.read_csv('Data (Raw CSV)/trades_round_0_day_-1.csv', sep=';')  

df4 = pd.read_csv('Data (Raw CSV)/trades_round_0_day_-2.csv', sep=';')

# %%
emeralds2 = df2[df2['product'] == 'EMERALDS'].copy()
tomatoes2 = df2[df2['product'] == 'TOMATOES'].copy()

plt.plot(emeralds2['timestamp'], emeralds2['mid_price'], label='EMERALDS')
plt.plot(tomatoes2['timestamp'], tomatoes2['mid_price'], label='TOMATOES')
plt.xlabel('Timestamp')
plt.ylabel('Mid Price')
plt.legend()
plt.title('Mid Price Over Time')
plt.show()

# %%
df3['price']
df3['quantity']
df3['symbol']

# filter by symbol
trades = df3[df3['symbol'] == 'EMERALDS']

# filter by buyer/seller
my_trades = df3[df3['buyer'] == 'SUBMISSION']
print(df.head())
# Out:
#    day  timestamp   product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -1          0  TOMATOES         4999             5         4998
# 1   -1          0  EMERALDS         9992            14         9990
# 2   -1        100  EMERALDS         9992            11         9990
# 3   -1        100  TOMATOES         5000             8         4998
# 4   -1        200  EMERALDS         9992            15         9990
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0            15          NaN           NaN         5013             5
# 1            29          NaN           NaN        10008            14
# 2            22          NaN           NaN        10008            11
# 3            21          NaN           NaN         5013             8
# 4            20          NaN           NaN        10008            15
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
plt.plot(tomatoes['timestamp'], tomatoes['mid_price'], label='TOMATOES')
plt.xlabel('Timestamp')
plt.ylabel('Mid Price')
plt.legend()
plt.title('Mid Price Over Time')
plt.show()

# %%
plt.plot(emeralds['timestamp'], emeralds['mid_price'], label='EMERALDS')
plt.xlabel('Timestamp')
plt.ylabel('Mid Price')
plt.legend()
plt.title('Mid Price Over Time')
plt.show()

# %%
plt.plot(tomatoes2['timestamp'], tomatoes2['mid_price'], label='TOMATOES')
plt.xlabel('Timestamp')
plt.ylabel('Mid Price')
plt.legend()
plt.title('Mid Price Over Time')
plt.show()
